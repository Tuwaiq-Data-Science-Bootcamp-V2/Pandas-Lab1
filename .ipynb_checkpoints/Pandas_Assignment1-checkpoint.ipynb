# %%
import pandas as pd

# %% [markdown]
# ## Q1: Create a Series with indexes = 1, 2, 3 and has three names.

# %%
index = [1, 2, 3]
names = ['manar', 'rahaf', 'khalda']
ser = pd.Series(names, index=index)
print(ser)
# Out:
# 1     manar
# 2     rahaf
# 3    khalda
# dtype: object

# %% [markdown]
# ## Q2: Change indexes to 11, 12, 13.

# %%
ser.index=[11,12,13]
ser
# Out:
# 11     manar
# 12     rahaf
# 13    khalda
# dtype: object

# %% [markdown]
# ## Q3: Retrieve First and second elements.

# %%
print(ser[11])
print(ser[12])
# Out:
# manar
# rahaf

# %% [markdown]
# ## Q4: Add duplicate elements, then remove the duplication

# %%
ser2 = pd.Series({14: 'lamess', 15: 'manar'})
ser = ser.append(ser2)
print(ser)
# Out:
# 11     manar
# 12     rahaf
# 13    khalda
# 14    lamess
# 15     manar
# dtype: object
# /var/folders/46/rns9fwqs7hndmyvxqyxmbq8c0000gn/T/ipykernel_41419/3640072946.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ser = ser.append(ser2)

# %%
ser.drop_duplicates()
# Out:
# 11     manar
# 12     rahaf
# 13    khalda
# 14    lamess
# dtype: object

# %% [markdown]
# ## Q5: Create a Students DataFrame has three columns (ID, Name)

# %%
data = {'ID': [101, 102, 103, 104],
        'Name': ['manar', 'rahaf', 'lamees', 'khalda']}

studentDF = pd.DataFrame(data, columns=['ID', 'Name'])
studentDF
# Out:
#     ID    Name
# 0  101   manar
# 1  102   rahaf
# 2  103  lamees
# 3  104  khalda

# %% [markdown]
# ## Q6: Read educ_figdp_1_Data.csv file

# %%
edu = pd.read_csv('educ_figdp_1_Data.csv')
edu
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# ...

# %% [markdown]
# ## Q7: What is the difference between loc and slicing?
# - loc use the index labels as references
# - slice use the position as references

# %%
edu.loc[0:5,:] #in loc show the data from 0 to 5
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
# 5  2005  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e
# 4  Total public expenditure on education as % of ...  4.95                  e
# 5  Total public expenditure on education as % of ...  4.92                  e

# %%
edu.loc[:,:]
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# ...

# %%
edu[0:5] #in slice show the data from 0 to 4 only, does not show indeex 5
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e
# 4  Total public expenditure on education as % of ...  4.95                  e

# %%
edu[:]
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# ...
