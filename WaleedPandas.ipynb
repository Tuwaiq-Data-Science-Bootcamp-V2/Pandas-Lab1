# %%
import pandas as pd

# %% [markdown]
# ## Q1: Create a Series with indexes = 1, 2, 3 and has three names.

# %%
list1 = ['waleed','mohammed','almutairi']
s1 = pd.Series(list1, index=[1,2,3])
print(s1)
# Out:
# 1       waleed
# 2     mohammed
# 3    almutairi
# dtype: object

# %% [markdown]
# ## Q2: Change indexes to 11, 12, 13.

# %%
s1 = pd.Series(list1, index=[11,12,13])
print(s1)
# Out:
# 11       waleed
# 12     mohammed
# 13    almutairi
# dtype: object

# %% [markdown]
# ## Q3: Retrieve First and second elements.

# %%
s1[:2]
# Out:
# 11      waleed
# 12    mohammed
# dtype: object

# %% [markdown]
# ## Q4: Add duplicate elements, then remove the duplication

# %%
s2 = pd.Series(['waleed','mohammed','aref'])
s1 = s1.append(s2)
print(s1)
# Out:
# 11       waleed
# 12     mohammed
# 13    almutairi
# 0        waleed
# 1      mohammed
# 2          aref
# 0        waleed
# 1      mohammed
# 2          aref
# dtype: object
# /var/folders/h8/w398rf8s3f32r74htxpdpc600000gn/T/ipykernel_1131/3443073040.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s1 = s1.append(s2)

# %%
s1.drop_duplicates()
# Out:
# 11       waleed
# 12     mohammed
# 13    almutairi
# 2          aref
# dtype: object

# %% [markdown]
# ## Q5: Create a Students DataFrame has three columns (ID, Name)

# %%
Data = {'ID':[],'Name':[]}
Students = pd.DataFrame(Data,columns=['ID','Name'])
Students
# Out:
# Empty DataFrame
# Columns: [ID, Name]
# Index: []

# %% [markdown]
# ## Q6: Read educ_figdp_1_Data.csv file

# %%
files = pd.read_csv('educ_figdp_1_Data.csv')
files
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# ...

# %% [markdown]
# ## Q7: What is the difference between loc and slicing?
# - loc use the index labels as references
# - slice use the position as references

# %%
files[30:40]
# Out:
#     TIME                            GEO  \
# 30  2006  European Union (25 countries)
# 31  2007  European Union (25 countries)
# 32  2008  European Union (25 countries)
# 33  2009  European Union (25 countries)
# 34  2010  European Union (25 countries)
# 35  2011  European Union (25 countries)
# 36  2000       Euro area (18 countries)
# 37  2001       Euro area (18 countries)
# 38  2002       Euro area (18 countries)
# 39  2003       Euro area (18 countries)
#
#                                              INDIC_ED Value Flag and Footnotes
# 30  Total public expenditure on education as % of ...  4.93                  e
# 31  Total public expenditure on education as % of ...  4.95                  e
# 32  Total public expenditure on education as % of ...  5.06                  e
# 33  Total public expenditure on education as % of ...  5.41                  e
# 34  Total public expenditure on education as % of ...  5.46                  e
# ...

# %%
files.loc[30:40,:]
# Out:
#     TIME                            GEO  \
# 30  2006  European Union (25 countries)
# 31  2007  European Union (25 countries)
# 32  2008  European Union (25 countries)
# 33  2009  European Union (25 countries)
# 34  2010  European Union (25 countries)
# 35  2011  European Union (25 countries)
# 36  2000       Euro area (18 countries)
# 37  2001       Euro area (18 countries)
# 38  2002       Euro area (18 countries)
# 39  2003       Euro area (18 countries)
# 40  2004       Euro area (18 countries)
#
#                                              INDIC_ED Value Flag and Footnotes
# 30  Total public expenditure on education as % of ...  4.93                  e
# 31  Total public expenditure on education as % of ...  4.95                  e
# 32  Total public expenditure on education as % of ...  5.06                  e
# 33  Total public expenditure on education as % of ...  5.41                  e
# 34  Total public expenditure on education as % of ...  5.46                  e
# ...

# %%
files.loc[30:40]
# Out:
#     TIME                            GEO  \
# 30  2006  European Union (25 countries)
# 31  2007  European Union (25 countries)
# 32  2008  European Union (25 countries)
# 33  2009  European Union (25 countries)
# 34  2010  European Union (25 countries)
# 35  2011  European Union (25 countries)
# 36  2000       Euro area (18 countries)
# 37  2001       Euro area (18 countries)
# 38  2002       Euro area (18 countries)
# 39  2003       Euro area (18 countries)
# 40  2004       Euro area (18 countries)
#
#                                              INDIC_ED Value Flag and Footnotes
# 30  Total public expenditure on education as % of ...  4.93                  e
# 31  Total public expenditure on education as % of ...  4.95                  e
# 32  Total public expenditure on education as % of ...  5.06                  e
# 33  Total public expenditure on education as % of ...  5.41                  e
# 34  Total public expenditure on education as % of ...  5.46                  e
# ...

# %%
files.loc[30:40,['TIME','Value']]
# Out:
#     TIME Value
# 30  2006  4.93
# 31  2007  4.95
# 32  2008  5.06
# 33  2009  5.41
# 34  2010  5.46
# 35  2011  5.31
# 36  2000     :
# 37  2001     :
# 38  2002  4.87
# 39  2003  4.89
# 40  2004  4.80
