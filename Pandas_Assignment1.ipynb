# %%
import pandas as pd

# %% [markdown]
# ## Q1: Create a Series with indexes = 1, 2, 3 and has three names.

# %%
Series1 =  pd.Series(['Ali', 'Mohammed', 'Ahmed'], index=[1, 2, 3])
Series1
# Out:
# 1         Ali
# 2    Mohammed
# 3       Ahmed
# dtype: object

# %% [markdown]
# ## Q2: Change indexes to 11, 12, 13.

# %%
Series1.index = [11,12,13]
Series1
# Out:
# 11         Ali
# 12    Mohammed
# 13       Ahmed
# dtype: object

# %% [markdown]
# ## Q3: Retrieve First and second elements.

# %%
Series1[:2]
# Out:
# 11         Ali
# 12    Mohammed
# dtype: object

# %% [markdown]
# ## Q4: Add duplicate elements, then remove the duplication

# %%
Series1 = pd.concat([Series1 , pd.Series(['Mohammed'], [14])])
Series1
# Out:
# 11         Ali
# 12    Mohammed
# 13       Ahmed
# 14    Mohammed
# 14    Mohammed
# dtype: object

# %%
Series1.drop_duplicates()
# Out:
# 11         Ali
# 12    Mohammed
# 13       Ahmed
# dtype: object

# %% [markdown]
# ## Q5: Create a Students DataFrame has three columns (ID, Name)

# %%
Data = {
    'ID': ['1014'],
    'Name': ['Ali Hussain']
}

StudentDF = pd.DataFrame(Data, columns=['ID', 'Name']) 

StudentDF
# Out:
#      ID         Name
# 0  1014  Ali Hussain

# %% [markdown]
# ## Q6: Read educ_figdp_1_Data.csv file

# %%
DataFromCSV = pd.read_csv('educ_figdp_1_Data.csv')

DataFromCSV
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# ...

# %% [markdown]
# ## Q7: What is the difference between loc and slicing?
# - loc use the index labels as references
# - slice use the position as references

# %%
# loc with specific columns
DataFromCSV.loc[5:15, ['GEO', 'Value']]
# Out:
#                               GEO Value
# 5   European Union (28 countries)  4.92
# 6   European Union (28 countries)  4.91
# 7   European Union (28 countries)  4.92
# 8   European Union (28 countries)  5.04
# 9   European Union (28 countries)  5.38
# 10  European Union (28 countries)  5.41
# 11  European Union (28 countries)  5.25
# 12  European Union (27 countries)  4.91
# 13  European Union (27 countries)  4.99
# 14  European Union (27 countries)  5.00
# 15  European Union (27 countries)  5.04

# %%
# loc
DataFromCSV.loc[5:15]
# Out:
#     TIME                            GEO  \
# 5   2005  European Union (28 countries)
# 6   2006  European Union (28 countries)
# 7   2007  European Union (28 countries)
# 8   2008  European Union (28 countries)
# 9   2009  European Union (28 countries)
# 10  2010  European Union (28 countries)
# 11  2011  European Union (28 countries)
# 12  2000  European Union (27 countries)
# 13  2001  European Union (27 countries)
# 14  2002  European Union (27 countries)
# 15  2003  European Union (27 countries)
#
#                                              INDIC_ED Value Flag and Footnotes
# 5   Total public expenditure on education as % of ...  4.92                  e
# 6   Total public expenditure on education as % of ...  4.91                  e
# 7   Total public expenditure on education as % of ...  4.92                  e
# 8   Total public expenditure on education as % of ...  5.04                  e
# 9   Total public expenditure on education as % of ...  5.38                  e
# ...

# %%
# slicing
DataFromCSV[5:15]
# Out:
#     TIME                            GEO  \
# 5   2005  European Union (28 countries)
# 6   2006  European Union (28 countries)
# 7   2007  European Union (28 countries)
# 8   2008  European Union (28 countries)
# 9   2009  European Union (28 countries)
# 10  2010  European Union (28 countries)
# 11  2011  European Union (28 countries)
# 12  2000  European Union (27 countries)
# 13  2001  European Union (27 countries)
# 14  2002  European Union (27 countries)
#
#                                              INDIC_ED Value Flag and Footnotes
# 5   Total public expenditure on education as % of ...  4.92                  e
# 6   Total public expenditure on education as % of ...  4.91                  e
# 7   Total public expenditure on education as % of ...  4.92                  e
# 8   Total public expenditure on education as % of ...  5.04                  e
# 9   Total public expenditure on education as % of ...  5.38                  e
# ...

# %%
# Selection
DataFromCSV[['TIME', 'GEO']]
# Out:
#      TIME                            GEO
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
# [384 rows x 2 columns]
