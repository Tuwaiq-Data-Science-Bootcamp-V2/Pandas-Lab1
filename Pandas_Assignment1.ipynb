# %%
import pandas as pd

# %% [markdown]
# ## Q1: Create a Series with indexes = 1, 2, 3 and has three names.

# %%
names = ['Nourah', 'Sarah', 'Ahmed']
index = [1,2,3]
s = pd.Series(names, index=index)
s
# Out:
# 1    Nourah
# 2     Sarah
# 3     Ahmed
# dtype: object

# %% [markdown]
# ## Q2: Change indexes to 11, 12, 13.

# %%
s.index = [11, 12, 13 ]
s
# Out:
# 11    Nourah
# 12     Sarah
# 13     Ahmed
# dtype: object

# %% [markdown]
# ## Q3: Retrieve First and second elements.

# %%
s[0:2]
# Out:
# 11    Nourah
# 12     Sarah
# dtype: object

# %% [markdown]
# ## Q4: Add duplicate elements, then remove the duplication

# %%
#Add duplicate elements
s4 = pd.Series({14 : 'Ahmed'})
s = s.append(s4)
s
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_7848\2115324193.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s = s.append(s4)
# 11    Nourah
# 12     Sarah
# 13     Ahmed
# 14     Ahmed
# dtype: object

# %%
#remove the duplication
s.drop_duplicates()
# Out:
# 11    Nourah
# 12     Sarah
# 13     Ahmed
# dtype: object

# %% [markdown]
# ## Q5: Create a Students DataFrame has three columns (ID, Name)

# %%
 students = {'Name': ['Kathey', 'Michael', 'William', 'Kathey', 'William', 'Kathey', 'Michael'],
        'ID': [111, 222, 333, 444, 555, 666, 777],
        
        
       }

x = pd.DataFrame(students, columns=['Name', 'ID',])
x
# Out:
#       Name   ID
# 0   Kathey  111
# 1  Michael  222
# 2  William  333
# 3   Kathey  444
# 4  William  555
# 5   Kathey  666
# 6  Michael  777

# %% [markdown]
# ## Q6: Read educ_figdp_1_Data.csv file

# %%
edu = pd.read_csv('educ_figdp_1_Data.csv')
edu
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# ...

# %% [markdown]
# ## Q7: What is the difference between loc and slicing?
# - loc use the index labels as references
# - slice use the position as references

# %%
#slicing does't inclued the end
edu[10:14]
# Out:
#     TIME                            GEO  \
# 10  2010  European Union (28 countries)
# 11  2011  European Union (28 countries)
# 12  2000  European Union (27 countries)
# 13  2001  European Union (27 countries)
#
#                                              INDIC_ED Value Flag and Footnotes
# 10  Total public expenditure on education as % of ...  5.41                  e
# 11  Total public expenditure on education as % of ...  5.25                  e
# 12  Total public expenditure on education as % of ...  4.91                  s
# 13  Total public expenditure on education as % of ...  4.99                  s

# %%
# loc inclued the end
edu.loc[10:14]
# Out:
#     TIME                            GEO  \
# 10  2010  European Union (28 countries)
# 11  2011  European Union (28 countries)
# 12  2000  European Union (27 countries)
# 13  2001  European Union (27 countries)
# 14  2002  European Union (27 countries)
#
#                                              INDIC_ED Value Flag and Footnotes
# 10  Total public expenditure on education as % of ...  5.41                  e
# 11  Total public expenditure on education as % of ...  5.25                  e
# 12  Total public expenditure on education as % of ...  4.91                  s
# 13  Total public expenditure on education as % of ...  4.99                  s
# 14  Total public expenditure on education as % of ...  5.00                  e
